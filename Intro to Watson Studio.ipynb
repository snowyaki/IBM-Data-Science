# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Jovanka Aurelia Purwanto</b>
# <br/>Biotechnologist

# %% [markdown]
# <i>I am interested in data science because it involves the fascination with big data and may be used in a variety of industries</i>

# %% [markdown]
# ### Cell5 will print a string "Hello Data Scientists"

# %%
print("Hello Data Scientists")
# Out:
# Hello Data Scientists

# %% [markdown]
# <ul>
#         <li>Great</li>
# <ol>
#         <li>Goodbye</li>
#
# <blockquote>Ice cream</blockquote>
